# %% [markdown]
# # Deep Learning with the Keras Library

# %% [markdown]
# **Goals:**
#
# - Learn how to **construct** and train a keras model on both classification and regression data.
#
# - Specifically this means, configuring model archectiture, compiling the algorithm, and fitting/predicting.
#
# - How to implement machine learning techniques that we know but in Keras (train/test split, cross validation)
#
# - We'll be using Keras on the front-end and TensorFlow on the backend, meaning we'll write code with Keras but the algorithms will be powered by TensorFlow.

# %% [markdown]
# ## Keras

# %%
#Imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.datasets.samples_generator import make_moons, make_regression

from keras.layers import Dense
from keras.models import Sequential
from keras.callbacks import EarlyStopping
from keras.utils.np_utils import to_categorical
# Out:
# Using TensorFlow backend.

# %% [markdown]
# You should see a message that says "Using TensorFlow Backend."
#
# If not, follow these instructions, but only after you've installed TensorFlow.
#
# Navigate to this directory in your terminal: `~/.keras/'`
#
# Type: `ls`
#
# You should see the following: `datasets	keras.json`
#
# We're going to edit the keras.json file using command line. Type: `nano keras.json`
#
# In the dictionary, change the value for the key "backend" to "tensorflow".
#
# Once you're finsihed, save/exit by following the instructions.

# %% [markdown]
# If you haven't installed Keras and TensorFlow.
# - Mac: https://www.pyimagesearch.com/2016/11/14/installing-keras-with-tensorflow-backend/
#
# - PC: https://www.lynda.com/Google-TensorFlow-tutorials/Installing-Keras-TensorFlow-backend-Windows/601801/642176-4.html

# %% [markdown]
# If it's not working, don't worry! Not a big deal, either find a tutorial online (stackoverflow) or ask me.

# %% [markdown]
# ## Classification Deep Learning

# %% [markdown]
# We're going to use the keras library to the fake moons dataset from sklearn

# %%
#Generate data
X, y = make_moons(n_samples=3000,
                    noise=0.12,
                    random_state=0)

# %%
#Visualize data

plt.style.use("fivethirtyeight")
plt.figure(figsize = (10, 8))

plt.scatter(X[:, 0], X[:, 1], c= y, alpha = 0.7, cmap = "RdBu");

# %% [markdown]
# 0 is red, 1 is blue

# %% [markdown]
# Before we make our keras model, how well would the following models work with this data: Logistic Regression, Decision Trees, and K-Nearest Neighbors

# %% [markdown]
# Time to design the model.
#
# Setting up a Keras model takes more work than your a Sklearn model.

# %%
#Intialization with Sequential

model = Sequential()

# %% [markdown]
# Adding an input layer to our model using the Dense function

# %%
#Specify number of features in data
n_cols = X.shape[1]

#Adding layer with 10 units, activation function set to relu

model.add(Dense(10, activation="relu", input_shape=(n_cols,)))

# %% [markdown]
# Add an output layer, the number of units must be equal to number of unique values in target variable, which in this case is 2. Use the sigmoid activation function

# %%
# Add the output layer
#Assign number of uniques to n_unique
n_unique = len(pd.unique(y))
model.add(Dense(n_unique, activation= "sigmoid"))

# %% [markdown]
# Here we compile the model, which means setting the optimization, loss, and metric paramaters

# %%
#Set optimzer to Stochastic Gradient Descent, loss to categorical_crossentropy, metrics = accuracy
model.compile(optimizer="sgd", loss = "categorical_crossentropy", metrics = ["accuracy"])

# %% [markdown]
# Before fitting, we have to binarize the target variable

# %%
y_binary = to_categorical(y)
y_binary
# Out:
# array([[ 1.,  0.],
#        [ 1.,  0.],
#        [ 0.,  1.],
#        ...,
#        [ 0.,  1.],
#        [ 0.,  1.],
#        [ 0.,  1.]])

# %%
#Null accuracy
pd.value_counts(y, normalize=True)
# Out:
# 1    0.5
# 0    0.5
# dtype: float64

# %% [markdown]
# Fitting time! Call .fit() like you would a sklearn model.

# %%
model.fit(X, y_binary, epochs=10)
# Out:
# Epoch 1/10
# 3000/3000 [==============================] - 0s 37us/step - loss: 0.6227 - acc: 0.7540
# Epoch 2/10
# 3000/3000 [==============================] - 0s 40us/step - loss: 0.5739 - acc: 0.8150
# Epoch 3/10
# 3000/3000 [==============================] - 0s 36us/step - loss: 0.5272 - acc: 0.8200
# Epoch 4/10
# 3000/3000 [==============================] - 0s 38us/step - loss: 0.4838 - acc: 0.8237
# Epoch 5/10
# 3000/3000 [==============================] - 0s 37us/step - loss: 0.4451 - acc: 0.8277
# Epoch 6/10
# 3000/3000 [==============================] - 0s 36us/step - loss: 0.4122 - acc: 0.8330
# Epoch 7/10
# 3000/3000 [==============================] - 0s 38us/step - loss: 0.3854 - acc: 0.8357
# Epoch 8/10
# 3000/3000 [==============================] - 0s 39us/step - loss: 0.3642 - acc: 0.8393
# Epoch 9/10
# 3000/3000 [==============================] - 0s 42us/step - loss: 0.3474 - acc: 0.8437
# Epoch 10/10
# 3000/3000 [==============================] - 0s 45us/step - loss: 0.3339 - acc: 0.8460

# %% [markdown]
# ## **CONGRATS ON MAKING YOUR FIRST DEEP LEARNING MODEL**

# %% [markdown]
# [Epoch defintion](https://deeplearning4j.org/glossary): "In machine-learning parlance, an epoch is a complete pass through a given dataset. That is, by the end of one epoch, your neural network will have been exposed to every record to example within the dataset once"
#
# <br>
#
# Epochs are another parameter that you have to configure and can have an effect on your model's performance.

# %% [markdown]
# Model tells use the log loss and accuracy scores for each epoch. Do you notice any trends in these scores for each epoch?

# %% [markdown]
# **Visualization time.** Like we did for previous, we're going to visualize the decision boundaries of this one layer neural net model.

# %%
#Load in the plot_decision_boundary function
def plot_decision_boundary(model, X, y):
    X_max = X.max(axis=0)
    X_min = X.min(axis=0)
    xticks = np.linspace(X_min[0], X_max[0], 100)
    yticks = np.linspace(X_min[1], X_max[1], 100)
    xx, yy = np.meshgrid(xticks, yticks)
    ZZ = model.predict(np.c_[xx.ravel(), yy.ravel()])[:, 1]
    Z = ZZ >= 0.5
    Z = Z.reshape(xx.shape)
    fig, ax = plt.subplots()
    ax = plt.gca()
    ax.contourf(xx, yy, Z, cmap="RdBu", alpha=0.2)
    ax.scatter(X[:,0], X[:,1], c=y,s=40,cmap="RdBu", alpha=0.4)
    plt.xlabel("Feature One")
    plt.ylabel("Feature Two")

# %%
#Use decision boundary function model and the data
plot_decision_boundary(model, X, y)

# %% [markdown]
# Thoughts on the results? How good is the model?

# %% [markdown]
# Make prediction on point (0,0). Works same way as sklearn.

# %%
point = np.array([[0, 0]])

model.predict(point)
# Out:
# array([[ 0.42302611,  0.33468473]], dtype=float32)

# %%
#these probabilities don't add up to 1.

# %% [markdown]
# Instead of outputting a 0 or 1, it gives the probabilites of the of both unique values.
#
# <br>
#
# `.predict_classes()` is predicting the class not probability

# %%
model.predict_classes(point)
# Out:
# array([0])

# %% [markdown]
# This is a very simple model, it only has one shallow layer. Let's add some more layers.

# %%
#Intialize
model = Sequential()

# Add the first layer
model.add(Dense(100, activation='relu', input_shape=(n_cols,)))

# Add the second layer
model.add(Dense(200, activation='relu'))


# Add the output layer with softmax activation function
model.add(Dense(2, activation="softmax"))

#Use adam optimizer
model.compile(optimizer="adam", loss = "categorical_crossentropy", metrics = ["accuracy"])

# %%
#Fit model with 30 epochs
model.fit(X, y_binary, epochs=40)
# Out:
# Epoch 1/40
# 3000/3000 [==============================] - 0s 85us/step - loss: 0.3176 - acc: 0.8540
# Epoch 2/40
# 3000/3000 [==============================] - 0s 59us/step - loss: 0.1828 - acc: 0.9177
# Epoch 3/40
# 3000/3000 [==============================] - 0s 60us/step - loss: 0.0937 - acc: 0.9657
# Epoch 4/40
# 3000/3000 [==============================] - 0s 59us/step - loss: 0.0418 - acc: 0.9877
# Epoch 5/40
# 3000/3000 [==============================] - 0s 65us/step - loss: 0.0217 - acc: 0.9953
# Epoch 6/40
# 3000/3000 [==============================] - 0s 72us/step - loss: 0.0154 - acc: 0.9973
# Epoch 7/40
# 3000/3000 [==============================] - 0s 66us/step - loss: 0.0109 - acc: 0.9983
# Epoch 8/40
# 3000/3000 [==============================] - 0s 59us/step - loss: 0.0090 - acc: 0.9980
# Epoch 9/40
# 3000/3000 [==============================] - 0s 58us/step - loss: 0.0098 - acc: 0.9967
# Epoch 10/40
# 3000/3000 [==============================] - 0s 59us/step - loss: 0.0086 - acc: 0.9977
# Epoch 11/40
# 3000/3000 [==============================] - 0s 63us/step - loss: 0.0092 - acc: 0.9973
# Epoch 12/40
# 3000/3000 [==============================] - 0s 68us/step - loss: 0.0077 - acc: 0.9973
# Epoch 13/40
# 3000/3000 [==============================] - 0s 66us/step - loss: 0.0072 - acc: 0.9973
# Epoch 14/40
# 3000/3000 [==============================] - 0s 59us/step - loss: 0.0079 - acc: 0.9973
# Epoch 15/40
# 3000/3000 [==============================] - 0s 62us/step - loss: 0.0065 - acc: 0.9987
# Epoch 16/40
# 3000/3000 [==============================] - 0s 60us/step - loss: 0.0062 - acc: 0.9980
# Epoch 17/40
# 3000/3000 [==============================] - 0s 62us/step - loss: 0.0082 - acc: 0.9963
# Epoch 18/40
# 3000/3000 [==============================] - 0s 59us/step - loss: 0.0066 - acc: 0.9977
# Epoch 19/40
# 3000/3000 [==============================] - 0s 59us/step - loss: 0.0061 - acc: 0.9983
# Epoch 20/40
# 3000/3000 [==============================] - 0s 64us/step - loss: 0.0055 - acc: 0.9983
# Epoch 21/40
# 3000/3000 [==============================] - 0s 61us/step - loss: 0.0070 - acc: 0.9977
# Epoch 22/40
# 3000/3000 [==============================] - 0s 60us/step - loss: 0.0048 - acc: 0.9990
# Epoch 23/40
# 3000/3000 [==============================] - 0s 68us/step - loss: 0.0059 - acc: 0.9977
# Epoch 24/40
# 3000/3000 [==============================] - 0s 67us/step - loss: 0.0067 - acc: 0.9980
# Epoch 25/40
# 3000/3000 [==============================] - 0s 66us/step - loss: 0.0050 - acc: 0.9983
# Epoch 26/40
# 3000/3000 [==============================] - 0s 59us/step - loss: 0.0054 - acc: 0.9983
# Epoch 27/40
# 3000/3000 [==============================] - 0s 62us/step - loss: 0.0066 - acc: 0.9970
# Epoch 28/40
# 3000/3000 [==============================] - 0s 70us/step - loss: 0.0054 - acc: 0.9980
# Epoch 29/40
# 3000/3000 [==============================] - 0s 71us/step - loss: 0.0056 - acc: 0.9980
# Epoch 30/40
# 3000/3000 [==============================] - 0s 68us/step - loss: 0.0059 - acc: 0.9983
# Epoch 31/40
# 3000/3000 [==============================] - 0s 69us/step - loss: 0.0043 - acc: 0.9987
# Epoch 32/40
# 3000/3000 [==============================] - 0s 62us/step - loss: 0.0077 - acc: 0.9973
# Epoch 33/40
# 3000/3000 [==============================] - 0s 60us/step - loss: 0.0064 - acc: 0.9970
# Epoch 34/40
# 3000/3000 [==============================] - 0s 62us/step - loss: 0.0062 - acc: 0.9973
# Epoch 35/40
# 3000/3000 [==============================] - 0s 62us/step - loss: 0.0059 - acc: 0.9980
# Epoch 36/40
# 3000/3000 [==============================] - 0s 65us/step - loss: 0.0059 - acc: 0.9987
# Epoch 37/40
# 3000/3000 [==============================] - 0s 63us/step - loss: 0.0054 - acc: 0.9980
# Epoch 38/40
# 3000/3000 [==============================] - 0s 62us/step - loss: 0.0057 - acc: 0.9973
# Epoch 39/40
# 3000/3000 [==============================] - 0s 60us/step - loss: 0.0051 - acc: 0.9983
# Epoch 40/40
# 3000/3000 [==============================] - 0s 61us/step - loss: 0.0040 - acc: 0.9987

# %% [markdown]
# How does the model perform now?

# %% [markdown]
# Let's *see* the difference

# %%
#Use decision boundary function model and the data
plot_decision_boundary(model, X, y)

# %% [markdown]
# How does that look to you? Better or worse than before? By how much?

# %%
#Look at model summary
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_3 (Dense)              (None, 100)               300
# _________________________________________________________________
# dense_4 (Dense)              (None, 200)               20200
# _________________________________________________________________
# dense_5 (Dense)              (None, 2)                 402
# =================================================================
# Total params: 20,902
# Trainable params: 20,902
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# We're trained a really good model, but principles of cross validation also to deep learning. Here's how we'll evaluate the model on a testing data.

# %%
#The same code for fitting a model as we used before but this time set validation_split to 0.25

#Intialize
model = Sequential()

# Add the first layer
model.add(Dense(100, activation='relu', input_shape=(n_cols,)))

# Add the second layer
model.add(Dense(200, activation='relu'))


# Add the output layer with softmax activation function
model.add(Dense(2, activation="sigmoid"))

#Use adam optimizer
model.compile(optimizer="adam", loss = "categorical_crossentropy", metrics = ["accuracy"])

model.fit(X, y_binary, epochs=40, validation_split = 0.25)
# Out:
# Train on 2250 samples, validate on 750 samples
# Epoch 1/40
# 2250/2250 [==============================] - 0s 112us/step - loss: 0.3944 - acc: 0.8440 - val_loss: 0.2397 - val_acc: 0.8853
# Epoch 2/40
# 2250/2250 [==============================] - 0s 69us/step - loss: 0.2392 - acc: 0.8711 - val_loss: 0.2097 - val_acc: 0.8960
# Epoch 3/40
# 2250/2250 [==============================] - 0s 63us/step - loss: 0.1924 - acc: 0.9147 - val_loss: 0.1377 - val_acc: 0.9427
# Epoch 4/40
# 2250/2250 [==============================] - 0s 67us/step - loss: 0.1246 - acc: 0.9502 - val_loss: 0.0821 - val_acc: 0.9760
# Epoch 5/40
# 2250/2250 [==============================] - 0s 66us/step - loss: 0.0687 - acc: 0.9764 - val_loss: 0.0461 - val_acc: 0.9907
# Epoch 6/40
# 2250/2250 [==============================] - 0s 62us/step - loss: 0.0422 - acc: 0.9867 - val_loss: 0.0297 - val_acc: 0.9947
# Epoch 7/40
# 2250/2250 [==============================] - 0s 69us/step - loss: 0.0269 - acc: 0.9947 - val_loss: 0.0172 - val_acc: 0.9960
# Epoch 8/40
# 2250/2250 [==============================] - 0s 67us/step - loss: 0.0171 - acc: 0.9978 - val_loss: 0.0132 - val_acc: 0.9960
# Epoch 9/40
# 2250/2250 [==============================] - 0s 74us/step - loss: 0.0139 - acc: 0.9973 - val_loss: 0.0142 - val_acc: 0.9973
# Epoch 10/40
# 2250/2250 [==============================] - 0s 73us/step - loss: 0.0123 - acc: 0.9978 - val_loss: 0.0108 - val_acc: 0.9960
# Epoch 11/40
# 2250/2250 [==============================] - 0s 71us/step - loss: 0.0100 - acc: 0.9987 - val_loss: 0.0094 - val_acc: 0.9973
# Epoch 12/40
# 2250/2250 [==============================] - 0s 71us/step - loss: 0.0097 - acc: 0.9978 - val_loss: 0.0100 - val_acc: 0.9973
# Epoch 13/40
# 2250/2250 [==============================] - 0s 74us/step - loss: 0.0089 - acc: 0.9987 - val_loss: 0.0094 - val_acc: 0.9960
# Epoch 14/40
# 2250/2250 [==============================] - 0s 73us/step - loss: 0.0082 - acc: 0.9987 - val_loss: 0.0106 - val_acc: 0.9973
# Epoch 15/40
# 2250/2250 [==============================] - 0s 68us/step - loss: 0.0087 - acc: 0.9973 - val_loss: 0.0070 - val_acc: 1.0000
# Epoch 16/40
# 2250/2250 [==============================] - 0s 63us/step - loss: 0.0067 - acc: 0.9996 - val_loss: 0.0067 - val_acc: 0.9973
# Epoch 17/40
# 2250/2250 [==============================] - 0s 65us/step - loss: 0.0080 - acc: 0.9978 - val_loss: 0.0206 - val_acc: 0.9933
# Epoch 18/40
# 2250/2250 [==============================] - 0s 70us/step - loss: 0.0086 - acc: 0.9978 - val_loss: 0.0064 - val_acc: 0.9973
# Epoch 19/40
# 2250/2250 [==============================] - 0s 71us/step - loss: 0.0065 - acc: 0.9982 - val_loss: 0.0064 - val_acc: 0.9973
# Epoch 20/40
# 2250/2250 [==============================] - 0s 75us/step - loss: 0.0074 - acc: 0.9978 - val_loss: 0.0076 - val_acc: 0.9973
# Epoch 21/40
# 2250/2250 [==============================] - 0s 67us/step - loss: 0.0089 - acc: 0.9969 - val_loss: 0.0151 - val_acc: 0.9933
# Epoch 22/40
# 2250/2250 [==============================] - 0s 64us/step - loss: 0.0079 - acc: 0.9978 - val_loss: 0.0111 - val_acc: 0.9960
# Epoch 23/40
# 2250/2250 [==============================] - 0s 73us/step - loss: 0.0066 - acc: 0.9978 - val_loss: 0.0058 - val_acc: 0.9973
# Epoch 24/40
# 2250/2250 [==============================] - 0s 76us/step - loss: 0.0054 - acc: 0.9987 - val_loss: 0.0129 - val_acc: 0.9947
# Epoch 25/40
# 2250/2250 [==============================] - 0s 70us/step - loss: 0.0062 - acc: 0.9987 - val_loss: 0.0127 - val_acc: 0.9947
# Epoch 26/40
# 2250/2250 [==============================] - 0s 67us/step - loss: 0.0059 - acc: 0.9987 - val_loss: 0.0065 - val_acc: 0.9973
# Epoch 27/40
# 2250/2250 [==============================] - 0s 68us/step - loss: 0.0055 - acc: 0.9991 - val_loss: 0.0070 - val_acc: 0.9973
# Epoch 28/40
# 2250/2250 [==============================] - 0s 68us/step - loss: 0.0064 - acc: 0.9973 - val_loss: 0.0109 - val_acc: 0.9960
# Epoch 29/40
# 2250/2250 [==============================] - 0s 69us/step - loss: 0.0061 - acc: 0.9982 - val_loss: 0.0079 - val_acc: 0.9973
# Epoch 30/40
# 2250/2250 [==============================] - 0s 69us/step - loss: 0.0047 - acc: 0.9991 - val_loss: 0.0072 - val_acc: 0.9987
# Epoch 31/40
# 2250/2250 [==============================] - 0s 79us/step - loss: 0.0061 - acc: 0.9978 - val_loss: 0.0069 - val_acc: 0.9973
# Epoch 32/40
# 2250/2250 [==============================] - 0s 72us/step - loss: 0.0047 - acc: 0.9996 - val_loss: 0.0058 - val_acc: 0.9973
# Epoch 33/40
# 2250/2250 [==============================] - 0s 72us/step - loss: 0.0045 - acc: 0.9987 - val_loss: 0.0061 - val_acc: 0.9973
# Epoch 34/40
# 2250/2250 [==============================] - 0s 66us/step - loss: 0.0058 - acc: 0.9973 - val_loss: 0.0123 - val_acc: 0.9973
# Epoch 35/40
# 2250/2250 [==============================] - 0s 72us/step - loss: 0.0103 - acc: 0.9947 - val_loss: 0.0051 - val_acc: 0.9987
# Epoch 36/40
# 2250/2250 [==============================] - 0s 65us/step - loss: 0.0054 - acc: 0.9978 - val_loss: 0.0083 - val_acc: 0.9973
# Epoch 37/40
# 2250/2250 [==============================] - 0s 64us/step - loss: 0.0043 - acc: 0.9996 - val_loss: 0.0065 - val_acc: 0.9973
# Epoch 38/40
# 2250/2250 [==============================] - 0s 65us/step - loss: 0.0039 - acc: 0.9991 - val_loss: 0.0115 - val_acc: 0.9960
# Epoch 39/40
# 2250/2250 [==============================] - 0s 60us/step - loss: 0.0042 - acc: 0.9991 - val_loss: 0.0111 - val_acc: 0.9973
# Epoch 40/40
# 2250/2250 [==============================] - 0s 63us/step - loss: 0.0048 - acc: 0.9987 - val_loss: 0.0080 - val_acc: 0.9973

# %% [markdown]
# Whats your assessment of the model now? Does it overfit?

# %%
#NO

# %% [markdown]
# ## Regression Deep Learning
#
# Now let's train a neural net on a regression dataset

# %%
#Make regression data
Xr, yr = make_regression(n_samples=2000, n_features=1, noise=2, random_state=4,bias = 0.9)

# %%
yr **=2

# %%
#Visualize
plt.figure(figsize=(8, 6))
plt.scatter(Xr, yr);

# %%
n_cols = Xr.shape[1]

#Intialize
model = Sequential()

# Add the first and only layer with 20 units and relu activation function
model.add(Dense(20, activation='relu', input_shape=(n_cols,)))


# Add the output layer with one unit. In regression, the output layer only has one unit.
model.add(Dense(1))

# %% [markdown]
# Compiler

# %%
#Use adam as optimizer function and set lose to mean_squared_error
model.compile(optimizer="adam", loss = "mean_squared_error")

# %%
#Fit model with 20 epochs
model.fit(Xr, yr, epochs = 20)
# Out:
# Epoch 1/20
# 2000/2000 [==============================] - 0s 102us/step - loss: 1357.1784
# Epoch 2/20
# 2000/2000 [==============================] - 0s 46us/step - loss: 1336.7755
# Epoch 3/20
# 2000/2000 [==============================] - 0s 48us/step - loss: 1312.7056
# Epoch 4/20
# 2000/2000 [==============================] - 0s 47us/step - loss: 1282.7585
# Epoch 5/20
# 2000/2000 [==============================] - 0s 47us/step - loss: 1246.2673
# Epoch 6/20
# 2000/2000 [==============================] - 0s 46us/step - loss: 1205.2289
# Epoch 7/20
# 2000/2000 [==============================] - 0s 47us/step - loss: 1161.2804
# Epoch 8/20
# 2000/2000 [==============================] - 0s 46us/step - loss: 1116.9199
# Epoch 9/20
# 2000/2000 [==============================] - 0s 44us/step - loss: 1072.7845
# Epoch 10/20
# 2000/2000 [==============================] - 0s 46us/step - loss: 1028.6381
# Epoch 11/20
# 2000/2000 [==============================] - 0s 46us/step - loss: 985.3459
# Epoch 12/20
# 2000/2000 [==============================] - 0s 46us/step - loss: 942.3124
# Epoch 13/20
# 2000/2000 [==============================] - 0s 52us/step - loss: 901.5453
# Epoch 14/20
# 2000/2000 [==============================] - 0s 48us/step - loss: 863.4052
# Epoch 15/20
# 2000/2000 [==============================] - 0s 48us/step - loss: 828.3461
# Epoch 16/20
# 2000/2000 [==============================] - 0s 48us/step - loss: 797.1818
# Epoch 17/20
# 2000/2000 [==============================] - 0s 48us/step - loss: 767.5920
# Epoch 18/20
# 2000/2000 [==============================] - 0s 46us/step - loss: 741.4545
# Epoch 19/20
# 2000/2000 [==============================] - 0s 46us/step - loss: 718.4326
# Epoch 20/20
# 2000/2000 [==============================] - 0s 47us/step - loss: 698.4056

# %% [markdown]
# Let's try it again but with train test split

# %%
model.fit(Xr, yr, epochs = 20, validation_split=.25)
# Out:
# Train on 1500 samples, validate on 500 samples
# Epoch 1/20
# 1500/1500 [==============================] - 0s 79us/step - loss: 605.1246 - val_loss: 906.3596
# Epoch 2/20
# 1500/1500 [==============================] - 0s 58us/step - loss: 593.7738 - val_loss: 892.8670
# Epoch 3/20
# 1500/1500 [==============================] - 0s 51us/step - loss: 583.2018 - val_loss: 880.0487
# Epoch 4/20
# 1500/1500 [==============================] - 0s 53us/step - loss: 572.9383 - val_loss: 868.8974
# Epoch 5/20
# 1500/1500 [==============================] - 0s 49us/step - loss: 563.6639 - val_loss: 856.1224
# Epoch 6/20
# 1500/1500 [==============================] - 0s 51us/step - loss: 554.1195 - val_loss: 845.2237
# Epoch 7/20
# 1500/1500 [==============================] - 0s 55us/step - loss: 545.1740 - val_loss: 834.3550
# Epoch 8/20
# 1500/1500 [==============================] - 0s 49us/step - loss: 536.4448 - val_loss: 824.2670
# Epoch 9/20
# 1500/1500 [==============================] - 0s 53us/step - loss: 528.1169 - val_loss: 813.9260
# Epoch 10/20
# 1500/1500 [==============================] - 0s 51us/step - loss: 519.9527 - val_loss: 803.6409
# Epoch 11/20
# 1500/1500 [==============================] - 0s 49us/step - loss: 511.7235 - val_loss: 794.2194
# Epoch 12/20
# 1500/1500 [==============================] - 0s 51us/step - loss: 503.9505 - val_loss: 784.0919
# Epoch 13/20
# 1500/1500 [==============================] - 0s 53us/step - loss: 495.9319 - val_loss: 775.4080
# Epoch 14/20
# 1500/1500 [==============================] - 0s 54us/step - loss: 488.2299 - val_loss: 765.3649
# Epoch 15/20
# 1500/1500 [==============================] - 0s 50us/step - loss: 480.6697 - val_loss: 756.5434
# Epoch 16/20
# 1500/1500 [==============================] - 0s 57us/step - loss: 473.2129 - val_loss: 747.1381
# Epoch 17/20
# 1500/1500 [==============================] - 0s 54us/step - loss: 465.9906 - val_loss: 737.9932
# Epoch 18/20
# 1500/1500 [==============================] - 0s 48us/step - loss: 458.7575 - val_loss: 729.9217
# Epoch 19/20
# 1500/1500 [==============================] - 0s 51us/step - loss: 452.0308 - val_loss: 721.1645
# Epoch 20/20
# 1500/1500 [==============================] - 0s 50us/step - loss: 445.3278 - val_loss: 712.6205

# %% [markdown]
# Visualize predictions

# %%
#Predictions

preds = model.predict(Xr)
preds
# Out:
# array([[ 45.75634766],
#        [ 17.81461143],
#        [ 23.75712395],
#        ...,
#        [ 13.82004547],
#        [ 16.82693291],
#        [ 28.33109283]], dtype=float32)

# %%
#Put predictions into dataframe for sorting purposes

pred_df = pd.DataFrame()

pred_df["feature"] = list(Xr)
pred_df["preds"] = list(preds)

# %%
#Sort dataframe

pred_df.sort_values("feature", inplace=True)

# %%
#Visualize
plt.figure(figsize=(8, 6))
plt.scatter(Xr, yr, alpha=.7)
plt.plot(pred_df.feature, pred_df.preds,c = "r",  alpha = 0.7);

# %% [markdown]
# How does that look?

# %% [markdown]
# **Back to the drawing board!**
#
# We need more layers!!

# %%
model = Sequential()

# Add the first layer with 50 units and relu activation function
model.add(Dense(100, activation='relu', input_shape=(n_cols,)))

# Add the second layer with 32 
model.add(Dense(100, activation='relu'))

# Add the output layer with no activation function
model.add(Dense(1))

#Compile with adam
model.compile(optimizer="adam", loss = "mean_squared_error")

# %%
#Fit model with 40 epochs
model.fit(Xr, yr, epochs = 40, validation_split=.25)
# Out:
# Train on 1500 samples, validate on 500 samples
# Epoch 1/40
# 1500/1500 [==============================] - 0s 245us/step - loss: 1196.3190 - val_loss: 1441.6937
# Epoch 2/40
# 1500/1500 [==============================] - 0s 62us/step - loss: 859.3305 - val_loss: 927.8854
# Epoch 3/40
# 1500/1500 [==============================] - 0s 64us/step - loss: 488.0624 - val_loss: 683.9562
# Epoch 4/40
# 1500/1500 [==============================] - 0s 63us/step - loss: 398.6813 - val_loss: 611.2909
# Epoch 5/40
# 1500/1500 [==============================] - 0s 63us/step - loss: 361.5494 - val_loss: 574.1954
# Epoch 6/40
# 1500/1500 [==============================] - 0s 61us/step - loss: 342.0698 - val_loss: 549.7028
# Epoch 7/40
# 1500/1500 [==============================] - 0s 69us/step - loss: 329.1497 - val_loss: 531.1041
# Epoch 8/40
# 1500/1500 [==============================] - 0s 61us/step - loss: 321.0720 - val_loss: 508.8511
# Epoch 9/40
# 1500/1500 [==============================] - 0s 65us/step - loss: 313.8687 - val_loss: 502.3899
# Epoch 10/40
# 1500/1500 [==============================] - 0s 69us/step - loss: 308.7515 - val_loss: 490.4388
# Epoch 11/40
# 1500/1500 [==============================] - 0s 63us/step - loss: 303.8412 - val_loss: 482.7241
# Epoch 12/40
# 1500/1500 [==============================] - 0s 67us/step - loss: 299.6392 - val_loss: 476.9522
# Epoch 13/40
# 1500/1500 [==============================] - 0s 74us/step - loss: 296.1634 - val_loss: 470.1966
# Epoch 14/40
# 1500/1500 [==============================] - 0s 66us/step - loss: 293.8434 - val_loss: 463.3389
# Epoch 15/40
# 1500/1500 [==============================] - 0s 66us/step - loss: 290.2986 - val_loss: 459.5670
# Epoch 16/40
# 1500/1500 [==============================] - 0s 68us/step - loss: 288.0363 - val_loss: 455.6334
# Epoch 17/40
# 1500/1500 [==============================] - 0s 63us/step - loss: 286.1031 - val_loss: 454.3644
# Epoch 18/40
# 1500/1500 [==============================] - 0s 64us/step - loss: 284.8641 - val_loss: 447.1745
# Epoch 19/40
# 1500/1500 [==============================] - 0s 64us/step - loss: 281.1595 - val_loss: 440.1282
# Epoch 20/40
# 1500/1500 [==============================] - 0s 64us/step - loss: 279.8786 - val_loss: 439.1590
# Epoch 21/40
# 1500/1500 [==============================] - 0s 63us/step - loss: 279.9654 - val_loss: 437.5341
# Epoch 22/40
# 1500/1500 [==============================] - 0s 63us/step - loss: 278.7687 - val_loss: 433.8620
# Epoch 23/40
# 1500/1500 [==============================] - 0s 61us/step - loss: 277.1903 - val_loss: 429.3388
# Epoch 24/40
# 1500/1500 [==============================] - 0s 68us/step - loss: 274.9119 - val_loss: 430.0264
# Epoch 25/40
# 1500/1500 [==============================] - 0s 65us/step - loss: 274.2356 - val_loss: 428.9887
# Epoch 26/40
# 1500/1500 [==============================] - 0s 64us/step - loss: 272.9248 - val_loss: 424.2101
# Epoch 27/40
# 1500/1500 [==============================] - 0s 63us/step - loss: 273.5646 - val_loss: 425.7900
# Epoch 28/40
# 1500/1500 [==============================] - 0s 68us/step - loss: 273.2126 - val_loss: 417.7855
# Epoch 29/40
# 1500/1500 [==============================] - 0s 64us/step - loss: 271.8624 - val_loss: 422.5801
# Epoch 30/40
# 1500/1500 [==============================] - 0s 64us/step - loss: 271.3823 - val_loss: 422.2052
# Epoch 31/40
# 1500/1500 [==============================] - 0s 66us/step - loss: 270.1010 - val_loss: 414.2017
# Epoch 32/40
# 1500/1500 [==============================] - 0s 64us/step - loss: 270.3331 - val_loss: 423.2374
# Epoch 33/40
# 1500/1500 [==============================] - 0s 64us/step - loss: 270.1677 - val_loss: 413.6941
# Epoch 34/40
# 1500/1500 [==============================] - 0s 65us/step - loss: 270.0893 - val_loss: 419.4939
# Epoch 35/40
# 1500/1500 [==============================] - 0s 63us/step - loss: 268.9030 - val_loss: 415.1576
# Epoch 36/40
# 1500/1500 [==============================] - 0s 65us/step - loss: 270.2314 - val_loss: 409.1664
# Epoch 37/40
# 1500/1500 [==============================] - 0s 73us/step - loss: 270.6115 - val_loss: 415.2873
# Epoch 38/40
# 1500/1500 [==============================] - 0s 62us/step - loss: 268.9777 - val_loss: 416.2113
# Epoch 39/40
# 1500/1500 [==============================] - 0s 64us/step - loss: 272.4150 - val_loss: 413.4581
# Epoch 40/40
# 1500/1500 [==============================] - 0s 65us/step - loss: 268.6045 - val_loss: 409.2093

# %%
#Predictions

preds = model.predict(Xr)
preds

#Put predictions into dataframe for sorting purposes

pred_df = pd.DataFrame()

pred_df["feature"] = list(Xr)
pred_df["preds"] = list(preds)

#Sort dataframe

pred_df.sort_values("feature", inplace=True)

# %%
#Visualize
plt.figure(figsize=(8, 6))
plt.scatter(Xr, yr, alpha=.7)
plt.plot(pred_df.feature, pred_df.preds,c = "r",  alpha = 0.7);

# %% [markdown]
# How does that look?

# %%
#Prediction
p = np.array([[0]])
model.predict(p)
# Out:
# array([[ 5.25539494]], dtype=float32)

# %%
#Model summary
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_37 (Dense)             (None, 100)               200
# _________________________________________________________________
# dense_38 (Dense)             (None, 100)               10100
# _________________________________________________________________
# dense_39 (Dense)             (None, 1)                 101
# =================================================================
# Total params: 10,401
# Trainable params: 10,401
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Let's visualize the performance over the epochs, but first we have to reset the model.

# %%
model = Sequential()

# Add the first layer with 50 units and relu activation function
model.add(Dense(100, activation='relu', input_shape=(n_cols,)))

# Add the second layer with 32 
model.add(Dense(100, activation='relu'))

# Add the output layer with no activation function
model.add(Dense(1))

#Compile with adam
model.compile(optimizer="adam", loss = "mean_squared_error")

# %%
#Re fit the model but set verbose to False and use 40 epochs and validation split to .3
#Assign model to m variable
m = model.fit(Xr, yr, epochs=40, validation_split=0.2, verbose=False)

# %%
#Call .history on m
m.history
# Out:
# {'loss': [1173.483662109375,
#   775.4881301879883,
#   471.56874420166014,
#   394.82713531494142,
#   363.67538360595705,
#   345.8806756591797,
#   332.61650390624999,
#   323.99301574707033,
#   321.54021621704101,
#   311.99388854980469,
#   309.42694412231447,
#   305.29051986694338,
#   304.24842605590823,
#   300.75303924560546,
#   298.07276168823245,
#   295.81923995971681,
#   292.55242492675779,
#   291.74736633300779,
#   287.98065505981447,
#   286.42117507934569,
#   283.96653427124022,
#   283.89533721923829,
#   282.41283981323244,
#   280.14947586059571,
#   278.64213562011719,
#   278.26045639038085,
#   277.80576110839843,
#   277.72548980712889,
#   275.69314773559569,
#   277.60461151123047,
#   274.78354980468748,
#   274.63679580688478,
#   274.43942367553711,
#   273.83677520751951,
#   274.31968231201171,
#   274.28468719482424,
#   274.39589859008788,
#   273.70208572387696,
#   274.22429367065428,
#   274.05071899414065],
#  'val_loss': [1415.1997998046875,
#   870.80545654296873,
#   693.02242309570318,
#   627.4652038574219,
#   589.3301953125,
#   567.97762573242187,
#   548.53673828125,
#   542.46992431640626,
#   520.29838684082029,
#   516.73762023925781,
#   502.04882568359375,
#   501.86857360839844,
#   489.94255371093749,
#   492.82338317871091,
#   484.41777587890624,
#   485.37039978027343,
#   471.06333129882813,
#   469.24066345214845,
#   464.04455078125,
#   460.52454650878906,
#   458.1727276611328,
#   459.23154418945313,
#   451.16221679687499,
#   449.1885290527344,
#   447.47268981933593,
#   444.89107055664061,
#   440.65444946289062,
#   434.87406005859373,
#   436.98462768554685,
#   438.2358447265625,
#   432.29893798828124,
#   430.71156311035156,
#   434.51496276855471,
#   424.98213378906252,
#   432.24918457031248,
#   424.16600585937499,
#   423.43302612304689,
#   424.87562011718751,
#   427.65400512695311,
#   425.44884033203124]}

# %% [markdown]
# We're going to plot the scores over the course of the epochs

# %%
plt.figure(figsize=(8, 8))
epochs = range(1, 41)
plt.plot(epochs, m.history['loss'],linewidth = 3, c = 'r')
plt.plot(epochs, m.history["val_loss"], linewidth =3)
plt.xlabel("Epochs")
plt.ylabel("Validation Score (MSE)");

# %% [markdown]
# What relationship do you see here? What does this tell us about our epochs?

# %% [markdown]
# We're going to use early stopping to save us time

# %%
#Intialize early_stopper object with patience = 1 and min_delta = 1

es = EarlyStopping(patience=1, min_delta=1)

# %% [markdown]
# Patience value indicates how many epochs of no improvement until the algorithms stops fitting.
#
# Min_delta value is the model improvement threshold it must meet in order to keep going.

# %% [markdown]
# Restart the model from the beginning.

# %%
model = Sequential()

# Add the first layer with 100 units and relu activation function
model.add(Dense(100, activation='relu', input_shape=(n_cols,)))

# Add the second layer with 100 
model.add(Dense(100, activation='relu'))

# Add the output layer with no activation function
model.add(Dense(1))

#Compile with adam
model.compile(optimizer="adam", loss = "mean_squared_error")

# %%
#Fit model on regresion data, use 40 epochs, validation split of .3
#Set callbacks equal to [es]
model.fit(Xr, yr, epochs=40, validation_split=0.2, callbacks=[es])
# Out:
# Train on 1600 samples, validate on 400 samples
# Epoch 1/40
# 1600/1600 [==============================] - 0s 279us/step - loss: 1224.6164 - val_loss: 1542.1462
# Epoch 2/40
# 1600/1600 [==============================] - 0s 64us/step - loss: 947.8073 - val_loss: 1085.6599
# Epoch 3/40
# 1600/1600 [==============================] - 0s 67us/step - loss: 560.6751 - val_loss: 750.9952
# Epoch 4/40
# 1600/1600 [==============================] - 0s 69us/step - loss: 421.6408 - val_loss: 665.4702
# Epoch 5/40
# 1600/1600 [==============================] - 0s 67us/step - loss: 378.5762 - val_loss: 617.7083
# Epoch 6/40
# 1600/1600 [==============================] - 0s 62us/step - loss: 357.4815 - val_loss: 587.8537
# Epoch 7/40
# 1600/1600 [==============================] - 0s 61us/step - loss: 340.8731 - val_loss: 571.0094
# Epoch 8/40
# 1600/1600 [==============================] - 0s 61us/step - loss: 330.1935 - val_loss: 547.6457
# Epoch 9/40
# 1600/1600 [==============================] - 0s 61us/step - loss: 321.3714 - val_loss: 538.2523
# Epoch 10/40
# 1600/1600 [==============================] - 0s 61us/step - loss: 315.6002 - val_loss: 525.3479
# Epoch 11/40
# 1600/1600 [==============================] - 0s 62us/step - loss: 311.1017 - val_loss: 516.3544
# Epoch 12/40
# 1600/1600 [==============================] - 0s 63us/step - loss: 305.9139 - val_loss: 508.6559
# Epoch 13/40
# 1600/1600 [==============================] - 0s 66us/step - loss: 302.5194 - val_loss: 498.3584
# Epoch 14/40
# 1600/1600 [==============================] - 0s 68us/step - loss: 299.9769 - val_loss: 493.2997
# Epoch 15/40
# 1600/1600 [==============================] - 0s 69us/step - loss: 295.3951 - val_loss: 486.7756
# Epoch 16/40
# 1600/1600 [==============================] - 0s 66us/step - loss: 293.2352 - val_loss: 475.4284
# Epoch 17/40
# 1600/1600 [==============================] - 0s 63us/step - loss: 290.7431 - val_loss: 475.9112

# %% [markdown]
# ## Bonus
#
# http://playground.tensorflow.org/

# %% [markdown]
# # Resources
#
# https://github.com/GeorgeMcIntire/collection_free_DL_resources

# %% [markdown]
# Articles:
#
# - https://towardsdatascience.com/activation-functions-neural-networks-1cbd9f8d91d6
#
# - https://towardsdatascience.com/learning-rate-schedules-and-adaptive-learning-rate-methods-for-deep-learning-2c8f433990d1
#
# - https://machinelearningmastery.com/adam-optimization-algorithm-for-deep-learning/
#
# - http://dataaspirant.com/2017/03/07/difference-between-softmax-function-and-sigmoid-function/
#
# - https://sefiks.com/2017/11/08/softmax-as-a-neural-networks-activation-function/
#
# - https://machinelearningmastery.com/using-learning-rate-schedules-deep-learning-models-python-keras/

# %% [markdown]
# # Class Lab Time
#
# 1. Make a function that returns a pre-initialized with a two layer Keras model. The choice of parameters are up to you.
#
# 2. Pick a supervised learning dataset (regression or classification) and use Keras to model that data. Compare results of the keras model to that of a logistic regression model. You're also more than welcome to use keras on your final project data as well.

# %% [markdown]
# OR

# %% [markdown]
# You can spend the rest of class working on your final project
